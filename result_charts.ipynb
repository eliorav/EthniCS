# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import pandas as pd
from EthniCS.services.graphics.render_experiments_charts import *
from EthniCS.constants import ethnicities_to_full_name_mapping, ethnicity_names
import plotly.io as pio

# %%
stats_folder = Path("./data/stats")
n=1024

# %% [markdown]
# ## EthniCS OVER AFR

# %%
super_population_stats_df = pd.read_csv(stats_folder/'super_population_stats.csv').drop(columns=['exp_num'])

# %%
fig = render_by_sparse_level(super_population_stats_df, metric='mse', sparsity_ratio1=0.01, sparsity_ratio2=0.07, num_of_pools=256, log_y1=True, log_y2=False, n=n)
# fig.write_image("AFR.jpg", scale=3, width=1200, height=800)
fig

# %%
render_by_sparse_level(super_population_stats_df, metric='mse', sparsity_ratio1=0.01, sparsity_ratio2=0.07, num_of_pools=256, log_y1=True, log_y2=False, n=n)

# %%
render_by_sparse_level(super_population_stats_df, metric='psnr', sparsity_ratio1=0.01, sparsity_ratio2=0.07, num_of_pools=256, log_y1=False, log_y2=False, n=n)

# %%
render_grid_error_bar_by_non_zero(super_population_stats_df, title_text='PSNR error bar by k over AFR')

# %%
render_grid_error_bar_by_num_of_pools(super_population_stats_df, range=np.arange(0.01, 0.11, 0.01), title_text='PSNR error bar by m over AFR')

# %% [markdown]
# ## EthniCS OVER HGDP+1000G

# %%
hdgp_data_stats_df = pd.read_csv(stats_folder/'HGDP_and_1000G_stats.csv').drop(columns=['exp_num'])

# %%
fig = render_by_ethnicity_num(hdgp_data_stats_df,  metric='mse', ethnicity_names=ethnicity_names, ethnicities_to_full_name_mapping=ethnicities_to_full_name_mapping, ethnicity_num1=7, ethnicity_num2=24, num_of_pools=256, log_y1=True, log_y2=True, n=n)

# fig.write_image("./images/HGDP_1000g.jpg", scale=3)
fig
# Out:
# <div>                            <div id="07b9a45f-5f38-4ceb-b98d-fcce108486ca" class="plotly-graph-div" style="height:900px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07b9a45f-5f38-4ceb-b98d-fcce108486ca")) {                    Plotly.newPlot(                        "07b9a45f-5f38-4ceb-b98d-fcce108486ca",                        [{"hovertemplate":"name=CoSaMP - identity\u003cbr\u003enum_of_pools=%{x}\u003cbr\u003emse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CoSaMP - identity","line":{"color":"#782AB6","dash":"solid","width":6},"marker":{"symbol":"circle","size":12},"mode":"markers+lines","name":"\u003cb\u003e\u003cb\u003eCoSaMP - identity\u003c\u002fb\u003e\u003c\u002fb\u003e","orientation":"v","showlegend":true,"x":[64,128,192,256,320,384,448,512],"xaxis":"x","y":[0
# ...

# %%
render_by_ethnicity_num(hdgp_data_stats_df,  metric='psnr', ethnicity_names=ethnicity_names, ethnicities_to_full_name_mapping=ethnicities_to_full_name_mapping, ethnicity_num1=1, ethnicity_num2=24, num_of_pools=256, log_y1=True, log_y2=True, n=n)
# Out:
# <div>                            <div id="441a1169-bf7d-4252-9ef3-1d242b5dedc4" class="plotly-graph-div" style="height:900px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("441a1169-bf7d-4252-9ef3-1d242b5dedc4")) {                    Plotly.newPlot(                        "441a1169-bf7d-4252-9ef3-1d242b5dedc4",                        [{"hovertemplate":"name=CoSaMP - identity\u003cbr\u003enum_of_pools=%{x}\u003cbr\u003epsnr=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CoSaMP - identity","line":{"color":"#782AB6","dash":"solid","width":6},"marker":{"symbol":"circle","size":12},"mode":"markers+lines","name":"\u003cb\u003e\u003cb\u003eCoSaMP - identity\u003c\u002fb\u003e\u003c\u002fb\u003e","orientation":"v","showlegend":true,"x":[64,128,192,256,320,384,448,512],"xaxis":"x","y":[
# ...

# %%
render_by_ethnicity_num(hdgp_data_stats_df,  metric='mse', ethnicity_names=ethnicity_names, ethnicities_to_full_name_mapping=ethnicities_to_full_name_mapping, ethnicity_num1=1, ethnicity_num2=24, num_of_pools=512, log_y1=True, log_y2=True, n=n)

# %%
render_by_sparse_level(hdgp_data_stats_df, metric='mse', sparsity_ratio1=0.08, sparsity_ratio2=0.18, num_of_pools=256, log_y1=True, log_y2=True, n=n)
# Out:
# <div>                            <div id="047d757e-a60a-4805-a2d3-2e66408cbdcc" class="plotly-graph-div" style="height:900px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("047d757e-a60a-4805-a2d3-2e66408cbdcc")) {                    Plotly.newPlot(                        "047d757e-a60a-4805-a2d3-2e66408cbdcc",                        [{"hovertemplate":"name=CoSaMP - identity\u003cbr\u003enum_of_pools=%{x}\u003cbr\u003emse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CoSaMP - identity","line":{"color":"#782AB6","dash":"solid","width":6},"marker":{"symbol":"circle","size":12},"mode":"markers+lines","name":"\u003cb\u003e\u003cb\u003eCoSaMP - identity\u003c\u002fb\u003e\u003c\u002fb\u003e","orientation":"v","showlegend":true,"x":[64,128,192,256,320,384,448,512],"xaxis":"x","y":[0
# ...

# %%
render_by_sparse_level(hdgp_data_stats_df, metric='psnr', sparsity_ratio1=0.08, sparsity_ratio2=0.18, num_of_pools=256, log_y1=True, log_y2=False, n=n)

# %% [markdown]
# ## EthniCS OVER 1000G

# %%
real_data_stats_df = pd.read_csv(stats_folder/'1000g_stats.csv').drop(columns=['exp_num'])

# %%
render_by_ethnicity_num(real_data_stats_df,  metric='mse', ethnicity_names=ethnicity_names, ethnicities_to_full_name_mapping=ethnicities_to_full_name_mapping, ethnicity_num1=1, ethnicity_num2=17, num_of_pools=256, log_y1=True, log_y2=True, n=n)
# Out:
# <div>                            <div id="a7d4379b-0d1f-4cca-9d96-b5d83ca91011" class="plotly-graph-div" style="height:900px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7d4379b-0d1f-4cca-9d96-b5d83ca91011")) {                    Plotly.newPlot(                        "a7d4379b-0d1f-4cca-9d96-b5d83ca91011",                        [{"hovertemplate":"name=CoSaMP - identity\u003cbr\u003enum_of_pools=%{x}\u003cbr\u003emse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CoSaMP - identity","line":{"color":"#782AB6","dash":"solid","width":6},"marker":{"symbol":"circle","size":12},"mode":"markers+lines","name":"\u003cb\u003e\u003cb\u003eCoSaMP - identity\u003c\u002fb\u003e\u003c\u002fb\u003e","orientation":"v","showlegend":true,"x":[64,128,192,256,320,384,448,512],"xaxis":"x","y":[0
# ...

# %%
render_by_sparse_level(real_data_stats_df, metric='mse', sparsity_ratio1=0.02, sparsity_ratio2=0.08, num_of_pools=256, log_y1=True, log_y2=False, n=n)

# %%
render_by_ethnicity_num(real_data_stats_df,  metric='psnr', ethnicity_names=ethnicity_names, ethnicities_to_full_name_mapping=ethnicities_to_full_name_mapping, ethnicity_num1=1, ethnicity_num2=17, num_of_pools=256, log_y1=True, log_y2=True, n=n)

# %%
render_by_sparse_level(real_data_stats_df, metric='psnr', sparsity_ratio1=0.02, sparsity_ratio2=0.08, num_of_pools=256, log_y1=True, log_y2=False, n=n)

# %%
render_grid_error_bar_by_non_zero(real_data_stats_df, title_text='PSNR error bar by k')

# %%
render_grid_error_bar_by_num_of_pools(real_data_stats_df, range=np.arange(0.02, 0.1, 0.01), title_text='PSNR error bar by m')

# %% [markdown]
# ## EthniCS OVER SIMULATED DATA

# %%
simulations_stats_df = pd.read_csv(stats_folder/'simulations_stats.csv').drop(columns=['exp_num'])
simulations_stats_df = simulations_stats_df[simulations_stats_df.original_sparsity_ratio < 0.25]

# %%
render_by_sparse_level(simulations_stats_df, metric='mse', sparsity_ratio1=0.01, sparsity_ratio2=0.08, num_of_pools=256, log_y1=True, log_y2=False, n=n)

# %%
render_by_sparse_level(simulations_stats_df, metric='psnr', sparsity_ratio1=0.01, sparsity_ratio2=0.08, num_of_pools=256, log_y1=True, log_y2=False, n=n)

# %%
render_grid_error_bar_by_non_zero(simulations_stats_df, title_text='PSNR error bar by k over simulated data')

# %%
render_grid_error_bar_by_num_of_pools(simulations_stats_df, range=np.arange(0.01, 0.21, 0.01), title_text='PSNR error bar by m over simulated data')
